# %% [markdown]
# ### Goal
# Analyze raw order data to compute core revenue quality metrics after cleaning and validation.

# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in /opt/anaconda3/lib/python3.13/site-packages (1.4.3)

# %%
import duckdb
import pandas as pd

# %%
orders = pd.read_csv("data/orders_raw.csv")

# %%
orders.head()
# Out:
#     order_id  user_id                        email_hash          order_ts_raw  \
# 0  ORD-14940     95.0  fe6e8699b47aced6c8f30f7f94f7ef8d      02/01/2024 02:17
# 1  ORD-28995    285.0  70f98e0a5b65109772648f23b5a01147            2024-02-09
# 2  ORD-10795      NaN                               NaN   2024-01-28 05:49:51
# 3  ORD-36156    104.0  6d25f5051bb9436ef042e2fdde2f0650  2024/05/14 22:39 GMT
# 4  ORD-96564    335.0  62666207dbaa3b80af7949ec7722372f      04/03/2024 15:11
#
#        amount_raw  currency    status
# 0  currency 98.61  currency      PAID
# 1           229.6       د.إ      Paid
# 2      aed 186.94       aed  COMPLETE
# 3            free  currency  COMPLETE
# 4          106.07       usd      PAID

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      267 non-null    object
#  1   user_id       229 non-null    float64
#  2   email_hash    213 non-null    object
#  3   order_ts_raw  265 non-null    object
#  4   amount_raw    267 non-null    object
#  5   currency      227 non-null    object
#  6   status        267 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 14.7+ KB

# %%
con = duckdb.connect()

# %%
con.register("orders_raw", orders)

# %% [markdown]
# ### Audit 1 - Order status inventory

# %%
con.execute("""SELECT status, COUNT(*) AS n FROM orders_raw
GROUP BY status
ORDER BY n DESC""").df()
# Out:
#       status   n
# 0   COMPLETE  44
# 1       Paid  42
# 2       paid  40
# 3    SUCCESS  40
# 4  completed  38
# 5    success  35
# 6       PAID  28

# %% [markdown]
# All observed statuses represent successful orders and will be normalized into a single canonical status: paid.

# %%
con.execute("""SELECT *,
CASE
WHEN LOWER(status) IN ('complete', 'completed', 'paid', 'success') 
THEN 'paid'
ELSE 'unknown'
END AS status_clean
FROM orders_raw""").df()
# Out:
#       order_id  user_id                        email_hash  \
# 0    ORD-14940     95.0  fe6e8699b47aced6c8f30f7f94f7ef8d
# 1    ORD-28995    285.0  70f98e0a5b65109772648f23b5a01147
# 2    ORD-10795      NaN                              None
# 3    ORD-36156    104.0  6d25f5051bb9436ef042e2fdde2f0650
# 4    ORD-96564    335.0  62666207dbaa3b80af7949ec7722372f
# ..         ...      ...                               ...
# 262  ORD-31544    426.0  1d22088823b0f562a727f56984b9e40d
# 263  ORD-81739      NaN                              None
# 264  ORD-96424    311.0  da9d56e411e0def651fbe4797b49bb8e
# 265  ORD-85213    424.0  cca60d7068fcc43d4487f73682b28cdb
# 266  ORD-59066    105.0                              None
#
#              order_ts_raw       amount_raw  currency     status status_clean
# 0        02/01/2024 02:17   currency 98.61  currency       PAID         paid
# 1              2024-02-09            229.6       د.إ       Paid         paid
# 2     2024-01-28 05:49:51       aed 186.94       aed   COMPLETE         paid
# 3    2024/05/14 22:39 GMT             free  currency   COMPLETE         paid
# 4        04/03/2024 15:11           106.07       usd       PAID         paid
# ..                    ...              ...       ...        ...          ...
# 262      02/11/2024 18:52            82.19       AED    SUCCESS         paid
# 263                  None           237.36       AED       PAID         paid
# 264      2024/01/17 12:47  currency 149.78  currency  completed         paid
# 265            2024-04-23            70.06       US$    success         paid
# 266            2024-02-29            75.69       aed   COMPLETE         paid
#
# [267 rows x 8 columns]

# %%
con.execute("""
SELECT status_clean, COUNT(*) AS n
FROM (
SELECT
CASE
WHEN LOWER(status) IN ('complete','completed','paid','success')
THEN 'paid'
ELSE 'unknown'
END AS status_clean
FROM orders_raw)
GROUP BY status_clean""").df()
# Out:
#   status_clean    n
# 0         paid  267

# %% [markdown]
# ### Audit 2 - amount_raw inventory

# %%
con.execute("""
SELECT amount_raw, COUNT(*) AS n
FROM orders_raw
GROUP BY amount_raw
ORDER BY n DESC
LIMIT 20""").df()
# Out:
#     amount_raw   n
# 0         free  11
# 1       162.16   2
# 2        70.72   2
# 3        93.19   1
# 4        16.09   1
# 5        86.46   1
# 6       145.48   1
# 7   aed 186.94   1
# 8       219.56   1
# 9        68.93   1
# 10      116.92   1
# 11       68.32   1
# 12      118.85   1
# 13      236.11   1
# 14       48.41   1
# 15  USD 117.59   1
# 16      128.47   1
# 17      159.59   1
# 18      337.41   1
# 19      122.09   1

# %% [markdown]
# Parse numeric values from strings, treat free as 0.0, anything unparseable, null

# %%
con.execute("""
SELECT amount_raw,
CASE
WHEN LOWER(TRIM(amount_raw)) = 'free' THEN 0
ELSE
TRY_CAST(REGEXP_EXTRACT(TRIM(amount_raw), '(-?\\d+(?:\\.\\d+)?)', 1) AS DOUBLE)
END AS amount_clean
FROM orders_raw
LIMIT 30;
""").df()
# Out:
#          amount_raw  amount_clean
# 0    currency 98.61         98.61
# 1             229.6        229.60
# 2        aed 186.94        186.94
# 3              free          0.00
# 4            106.07        106.07
# 5             195.8        195.80
# 6              81.8         81.80
# 7             62.16         62.16
# 8        aed 111.65        111.65
# 9             93.19         93.19
# 10            80.06         80.06
# 11           574.33        574.33
# 12            68.93         68.93
# 13             free          0.00
# 14       د.إ 277.18        277.18
# 15             free          0.00
# 16            62.05         62.05
# 17            78.96         78.96
# 18           128.05        128.05
# 19            71.72         71.72
# 20  currency 135.73        135.73
# 21            76.71         76.71
# 22            81.11         81.11
# 23           124.43        124.43
# 24           124.42        124.42
# 25           102.56        102.56
# 26           185.25        185.25
# 27            16.09         16.09
# 28            89.05         89.05
# 29            98.99         98.99

# %% [markdown]
# ### Audit 3 - currency inventory

# %%
con.execute("""SELECT currency, COUNT(*) AS n FROM orders_raw
GROUP BY currency
ORDER BY n DESC""").df()
# Out:
#    currency   n
# 0      None  40
# 1       AED  39
# 2       aed  35
# 3       usd  34
# 4  currency  33
# 5       US$  33
# 6       د.إ  30
# 7       USD  23

# %%
con.execute("""SELECT amount_raw, currency,
CASE
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('aed', 'د.إ') THEN 'AED'
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('usd', 'us$') THEN 'USD'
WHEN currency IS NULL OR LOWER(TRIM(currency)) = 'currency' THEN
CASE
WHEN LOWER(TRIM(amount_raw)) LIKE '%usd%' OR 
LOWER(TRIM(amount_raw)) LIKE '%us$%' THEN 'USD'
WHEN LOWER(amount_raw) LIKE '%aed%' OR TRIM(amount_raw) LIKE '%د.إ%' THEN 'AED'
ELSE NULL
END
ELSE NULL
END AS currency_clean
FROM orders_raw
LIMIT 50;""").df()
# Out:
#          amount_raw  currency currency_clean
# 0    currency 98.61  currency           None
# 1             229.6       د.إ            AED
# 2        aed 186.94       aed            AED
# 3              free  currency           None
# 4            106.07       usd            USD
# 5             195.8       US$            USD
# 6              81.8       US$            USD
# 7             62.16       US$            USD
# 8        aed 111.65       aed            AED
# 9             93.19       د.إ            AED
# 10            80.06       usd            USD
# 11           574.33       د.إ            AED
# 12            68.93       AED            AED
# 13             free       USD            USD
# 14       د.إ 277.18       د.إ            AED
# 15             free       usd            USD
# 16            62.05       aed            AED
# 17            78.96       USD            USD
# 18           128.05      None           None
# 19            71.72       AED            AED
# 20  currency 135.73  currency           None
# 21            76.71       AED            AED
# 22            81.11       AED            AED
# 23           124.43  currency           None
# 24           124.42       AED            AED
# 25           102.56       usd            USD
# 26           185.25      None           None
# 27            16.09       USD            USD
# 28            89.05       د.إ            AED
# 29            98.99      None           None
# 30           164.27       US$            USD
# 31            196.6       د.إ            AED
# 32            68.32       US$            USD
# 33           178.04  currency           None
# 34           162.16      None           None
# 35           236.11       aed            AED
# 36           219.56      None           None
# 37           130.81  currency           None
# 38            20.52       aed            AED
# 39            91.13       AED            AED
# 40           220.69  currency           None
# 41            43.71      None           None
# 42        usd 64.53       usd            USD
# 43            83.58       USD            USD
# 44           142.57       د.إ            AED
# 45           265.17       USD            USD
# 46           240.33      None           None
# 47            67.81       US$            USD
# 48            88.81       US$            USD
# 49        usd 13.36       usd            USD

# %%
con.execute("""
WITH tmp AS (SELECT
CASE
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('aed', 'د.إ') THEN 'AED'
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('usd', 'us$') THEN 'USD'
WHEN currency IS NULL OR LOWER(TRIM(currency)) = 'currency' THEN
CASE
WHEN LOWER(TRIM(amount_raw)) LIKE '%usd%' OR 
LOWER(TRIM(amount_raw)) LIKE '%us$%' THEN 'USD'
WHEN LOWER(amount_raw) LIKE '%aed%' OR TRIM(amount_raw) LIKE '%د.إ%' THEN 'AED'
ELSE NULL
END
ELSE NULL
END AS currency_clean
FROM orders_raw)
SELECT SUM(CASE WHEN currency_clean IS NULL THEN 1 ELSE 0 END) AS null_currency_clean
FROM tmp;""").df()
# Out:
#    null_currency_clean
# 0                 69.0

# %%
con.execute("""
CREATE OR REPLACE VIEW clean_orders AS 
SELECT order_id, user_id, email_hash, order_ts_raw,
CASE
WHEN LOWER(TRIM(amount_raw)) = 'free' THEN 0
ELSE
TRY_CAST(REGEXP_EXTRACT(TRIM(amount_raw), '(-?\\d+(?:\\.\\d+)?)', 1) AS DOUBLE)
END AS amount_clean,
amount_raw,
CASE
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('aed', 'د.إ') THEN 'AED'
WHEN currency IS NOT NULL AND LOWER(TRIM(currency)) IN ('usd', 'us$') THEN 'USD'
WHEN currency IS NULL OR LOWER(TRIM(currency)) = 'currency' THEN
CASE
WHEN LOWER(TRIM(amount_raw)) LIKE '%usd%' OR 
LOWER(TRIM(amount_raw)) LIKE '%us$%' THEN 'USD'
WHEN LOWER(amount_raw) LIKE '%aed%' OR TRIM(amount_raw) LIKE '%د.إ%' THEN 'AED'
ELSE NULL
END
ELSE NULL
END AS currency_clean,
currency,
CASE
WHEN LOWER(status) IN ('complete','completed','paid','success')
THEN 'paid'
ELSE 'unknown'
END AS status_clean,
status,
CASE
WHEN LOWER(TRIM(amount_raw)) <> 'free'
AND TRY_CAST(REGEXP_EXTRACT(TRIM(amount_raw), '(-?\\d+(?:\\.\\d+)?)', 1) AS DOUBLE) IS NULL
THEN TRUE ELSE FALSE
END AS flag_bad_amount,
CASE
WHEN currency_clean IS NULL THEN TRUE 
ELSE FALSE
END AS flag_missing_currency
FROM orders_raw;""")

# %% [markdown]
# Sanity Checks

# %%
con.execute("SELECT COUNT(*) FROM clean_orders").df()
# Out:
#    count_star()
# 0           267

# %%
con.execute("""SELECT SUM(flag_bad_amount::INT) AS bad_amounts
FROM clean_orders""").df()
# Out:
#    bad_amounts
# 0          0.0

# %%
con.execute("""SELECT currency_clean, COUNT(*) AS n FROM clean_orders
GROUP BY currency_clean
ORDER BY n DESC""").df()
# Out:
#   currency_clean    n
# 0            AED  104
# 1            USD   94
# 2           None   69

# %% [markdown]
# ### Final Metrics

# %% [markdown]
# Total Revenue by Currency

# %%
con.execute("""SELECT currency_clean, ROUND(SUM(amount_clean), 2) AS total_revenue
FROM clean_orders
WHERE status_clean = 'paid'
GROUP BY currency_clean
ORDER BY total_revenue DESC""").df()
# Out:
#   currency_clean  total_revenue
# 0            AED       13630.25
# 1            USD        9946.20
# 2           None        8197.71

# %% [markdown]
# Average Order Value (AOV)

# %%
con.execute("""SELECT currency_clean, ROUND(AVG(amount_clean), 2) AS aov
FROM clean_orders
WHERE status_clean = 'paid'
GROUP BY currency_clean""").df()
# Out:
#   currency_clean     aov
# 0           None  118.81
# 1            AED  131.06
# 2            USD  105.81

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Out of 267 total orders, all observed statuses mapped to successful payments, while approximately 26% of orders lacked an explicit currency and were treated separately to avoid mixing revenue units.
# This analysis highlights the importance of isolating transactional integrity from behavioral funnels and demonstrates how careful data cleaning enables reliable revenue metrics such as total revenue and average order value.
